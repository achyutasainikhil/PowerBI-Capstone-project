# %%
import git
import pandas as pd

# Clone the Git repository
repo_url = 'https://github.com/achyutasainikhil/PowerBI-Capstone-project.git'
repo_path = 'achyutasainikhil/PowerBI-Capstone-project'
git.Repo.clone_from(repo_url, repo_path)

# # Path to the file you want to extract
file_path = 'achyutasainikhil/AnnualData2/Annual supply and utilization - Dry whey, annual.csv'

# # Read the file into a DataFrame
df = pd.read_csv(file_path)

# # Now you have your DataFrame ready to use
print(df.head())
# Out:
#    Year  Supply Beginning manufacturers' stocks For animal use \r\n[A]  \
# 0  2011                                                4.4
# 1  2012                                                4.2
# 2  2013                                                3.4
# 3  2014                                                0.5
# 4  2015                                                0.8
#
#    Supply Beginning manufacturers' stocks For human use \r\n[B]  \
# 0                                               42.6
# 1                                               42.1
# 2                                               56.1
# 3                                               62.2
# 4                                               64.7
#
#    Supply Beginning manufacturers' stocks Total \r\n[C] \r\n= [A + B]  \
# 0                                               47.0
# 1                                               46.3
# 2                                               59.6
# 3                                               62.7
# 4                                               65.4
#
#    Supply Production For animal use \r\n[D]  \
# 0                                      59.3
# 1                                      52.9
# 2                                      36.9
# 3                                      13.7
# 4                                      16.7
#
#   Supply Production For human use \r\n[E]  \
# 0                                   950.9
# 1                                     946
# 2                                   916.1
# 3                                     856
# 4                                   960.9
#
#    Total Supply Production\r\n[F] \r\n= [D + E]  Supply Imports \r\n[G]  \
# 0                                      1,010.10                     0.1
# 1                                         998.9                     0.0
# 2                                           953                     0.0
# 3                                         869.7                     0.0
# 4                                         977.6                     0.0
#
#   Total supply\r\n= [C + F + G]  Utilization Exports\r\n[I]  \
# 0                      1,057.20                       550.5
# 1                      1,045.20                       478.2
# 2                      1,012.60                       521.4
# 3                         932.4                       504.4
# 4                      1,043.00                       395.2
#
#    Utilization Ending manufacturers' stocks For animal use \r\n[J]  \
# 0                                                4.2
# 1                                                3.4
# 2                                                0.5
# 3                                                0.8
# 4                                                2.2
#
#    Utilization Ending manufacturers' stocks For human use \r\n[K]  \
# 0                                               42.1
# 1                                               56.1
# 2                                               62.2
# 3                                               64.7
# 4                                               70.6
#
#    Total Utilization Ending manufacturers' stocks \r\n[L] \r\n= [J + K]  \
# 0                                               46.3
# 1                                               59.6
# 2                                               62.7
# 3                                               65.4
# 4                                               72.7
#
#    Domestic disappearance \r\n[M] \r\n= [H - I - L]  \
# 0                                             460.4
# 1                                             507.4
# 2                                             428.5
# 3                                             362.6
# 4                                             575.0
#
#    Annual adjustments Net shipments to U.S. territories\r\n[N]  \
# 0                                                0.2
# 1                                                0.2
# 2                                                0.1
# 3                                                0.2
# 4                                                0.3
#
#    Annual adjustments Domestic animal feed use\r\n[O]  \
# 0                                              148.9
# 1                                              105.9
# 2                                               84.8
# 3                                               71.9
# 4                                               92.3
#
#    Apparent domestic human use\r\n= [M - N - O]
# 0                                         311.3
# 1                                         401.3
# 2                                         343.6
# 3                                         290.5
# 4                                         482.4

# %%
# Local path to the existing repository
repo_path = 'achyutasainikhil/AnnualData2'

# Open the existing repository
repo = git.Repo(repo_path)

# Pull changes from the remote repository
origin = repo.remotes.origin
origin.pull()

# Path to the file you want to extract
Dry_path = 'achyutasainikhil/AnnualData2/Annual supply and utilization - Dry whey, annual.csv'
WPC_path = 'achyutasainikhil/AnnualData2/Annual supply and utilization - WPC, annual.csv'


# Read the file into a DataFrame
Dry_path_df = pd.read_csv(Dry_path)
WPC_path_df = pd.read_csv(WPC_path)


Dry_path_df['incredient'] = 'dry'
WPC_path_df['incredient'] = 'wpc'


merged_df = pd.concat([Dry_path_df, WPC_path_df], ignore_index=True)

merged_df.to_excel('merged_data2.xlsx', index=False)
